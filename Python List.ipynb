# %% [markdown]
# <a href="https://www.viharatech.com"><img src="https://miro.medium.com/v2/resize:fit:828/format:webp/1*on2Bpj6A5gfd-CzaFOAZRA.jpeg"></a>
#
#
# - `Welcome to our interactive learning session! In this Jupyter notebook, you'll find a series of questions related to Python List Concept. To maximize your learning, please write Python code in the cell below each question and execute it. This hands-on practice will help reinforce your understanding of the concepts. Feel free to reach out if you have any questions or need assistance. Happy coding! 💻🐍 `

# %% [markdown]
# ### Question 1: Write a Python program to count the number of elements in a list.
#
#
# - `sample input : `
#     - `var = [10,11,12,13]`
# - `sample output :`
#     - `result : 4`

# %%
# Please write The solution Here for above question 1:
var = [10,11,12,13]
result = len(var)
print("result:",result)
# Out:
# result: 4

# %% [markdown]
# ### Question 2: Write a Python program to find the maximum and minimum values in a given list.
#
# - `sample input : `
#     - `var = [10,11,12,13,14,15]`
# - `sample output :`
#     - `result : max = 15 , min = 10`

# %%
# Please write The solution Here for above question 2:
var=[10,11,12,13,14,15]
result=max(var)
res=min(var)
print("result: max =",result,",","min =",res)
# Out:
# result: max = 15 , min = 10

# %% [markdown]
# ### Question 3: Write a Python program to remove the first occurrence of a specified element from a list.
#
# - `sample input : `
#     - `var = [1,2,3,4,2,5]`
# - `sample output :`
#     - `result : [1,3,4,2,5]`

# %%
# Please write The solution Here for above question 3:
var=[1,2,3,4,2,5]
del(var[1])
print("result :" ,var)
# Out:
# result : [1, 3, 4, 2, 5]

# %% [markdown]
# ### Question 4: Write a Python program to find the average of all the elements in a list.
#
#
# - `sample input : `
#     - `var = [1,2,3,4,2,5]`
# - `sample output :`
#     - `result : 2.833 `

# %%
# Please write The solution Here for above question 4:
var=[1,2,3,4,2,5]
result=sum(var)/len(var)
print("result :" ,round(result,3))
# Out:
# result : 2.833

# %% [markdown]
# ### Question 5: Write a Python program to check if a list is empty or not.
#
#
# - `sample input : `
#     - `var1 = [1,2]`
# - `sample output :`
#     - `result : Not empty`
#
# - `sample input : `
#     - `var1 = []`
# - `sample output :`
#     - `result :empty`

# %%
# Please write The solution Here for above question 5:
def check_if_empty(var):
    if not var:
        return "result: empty"
    else:
        return "result: Not empty"


var1 = [1, 2]
var2 = []


print(check_if_empty(var1))  
print(check_if_empty(var2))
# Out:
# result: Not empty
# result: empty

# %% [markdown]
# ### Question 6:  Write a Python program to find the index of a specified element in a list..
#
# - `sample input : `
#     - `var = [1,2,3,4,2,5]`
# - `sample output :`
#     - `result : 3 index is 2`

# %%
# Please write The solution Here for above question 6:
var=[1,2,3,4,2,5]
a=3
index=var.index(a)

print("result :",a, "index is ",index)
# Out:
# result : 3 index is  2

# %% [markdown]
# ### Question 7: Write a Python program to find which number is palindrome in below given list .
#
# - `sample input : `
#     - `var = [134,121,155]`
# - `sample output :`
#     - `result : 134 is not a palindome , 121 is a palindrome `

# %%
# Please write The solution Here for above question 7:
def is_palindrome(number):
    s = str(number)
    return s == s[::-1]
var = [134, 121, 155]
results = []
for num in var:
    if is_palindrome(num):
        results.append(f"{num} is a palindrome")
        break;
    else:
        results.append(f"{num} is not a palindrome")
        
print("result:", ", ".join(results))
# Out:
# result: 134 is not a palindrome, 121 is a palindrome

# %% [markdown]
# ### Question 8: Write a Python program to find the common elements between two lists.
#
# - `sample input : `
#     - `var1 = [1,2,3,4,10]`
#     - `var2 = [10,11,12,14]`
# - `sample output :`
#     - `result : 10`

# %%
# Please write The solution Here for above question 8:
var1 = [1,2,3,4,10]
var2 = [10,11,12,14]
common_elements=list(set(var1)&set(var2))
print("result : ",common_elements)
# Out:
# result :  [10]

# %% [markdown]
# ### Question 9: Write a Python program to remove the duplicates from a list
#
# - `sample input : `
#     - `var = [10,11,12,10,12,24]`
# - `sample output :`
#     - `result : [10,11,12,24]`

# %%
# Please write The solution Here for above question 9:
var=[10,11,12,10,12,24]
remove_duplicate=list(set(var))
print("result : ",remove_duplicate)
# Out:
# result :  [24, 10, 11, 12]

# %% [markdown]
# ### Question 10:  Write a Python program to sort a list of strings in Ascii Order [Ascending order]
#
#
# - `sample input : `
#     - `var = ['a' , 'c' , 'b']`
# - `sample output :`
#     - `result : ['a' , 'b' , 'c']`

# %%
# Please write The solution Here for above question 10:
var=['a','c','b']
var.sort()
print("result:",var)
# Out:
# result: ['a', 'b', 'c']
